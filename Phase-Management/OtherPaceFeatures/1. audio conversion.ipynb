# %%
pip install librosa pandas torchaudio scikit-learn matplotlib pydub openai-whisper ffmpeg-python soundfile noisereduce fastapi uvicorn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 1.8 MB 839 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 7.8 MB 5.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 803 kB 4.4 MB/s eta 0:00:01
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/jj/v94g6xv93wl2xxv1rn_6cz3h0000gp/T/pip-build-env-_t1k49hz/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/jj/v94g6xv93wl2xxv1rn_6cz3h0000gp/T/pip-build-env-_t1k49hz/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
# ...

# %%
# Out:
# Converted: AUDIO-2025-07-21-11-52-277.m4a
# Converted: AUDIO-2025-07-21-11-54-596.m4a
# Converted: AUDIO-2025-07-21-11-52-27.m4a
# Converted: AUDIO-2025-07-21-11-55-02.m4a
# Converted: AUDIO-2025-07-21-11-54-586.m4a
# Converted: AUDIO-2025-07-21-11-54-57.m4a
# Converted: AUDIO-2025-07-21-11-55-01.m4a
# Converted: AUDIO-2025-07-21-11-55-00.m4a
# Converted: AUDIO-2025-07-21-11-55-051.m4a
# Converted: AUDIO-2025-07-21-11-54-10.m4a
# Converted: AUDIO-2025-07-21-11-54-59.m4a
# Converted: AUDIO-2025-07-21-11-51-4333.m4a
# Converted: AUDIO-2025-07-21-11-54-576.m4a
# Converted: AUDIO-2025-07-21-11-51-433.m4a
# Converted: Samy6.m4a
# Converted: AUDIO-2025-07-21-11-54-588.m4a
# Converted: Samy7.m4a
# Converted: AUDIO-2025-07-21-11-54-58.m4a
# Converted: Samy5.m4a
# Converted: AUDIO-2025-07-21-11-51-42.m4a
# Converted: AUDIO-2025-07-21-11-51-43.m4a
# Converted: Samy4.m4a
# Converted: AUDIO-2025-07-21-11-55-010.m4a
# Converted: samy1.m4a
# Converted: Samy3.m4a
# ...
